# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import make_scorer, recall_score, accuracy_score, f1_score, precision_score

# %%
# Definiciones globales

# %run ../Lib/pandas_options.py
# %run ../Lib/define_constantes.py

# %%
# Cargar datos ya preprocesados y dividirlos en variables independientes (X) y variable dependiente objetivo (Y)

archivo_datos_codificados = f'{DIRECTORIO_DATOS_PREPROCESADOS}/DATOSCODIFICADOS.csv'
df_datos_codificados = pd.read_csv(archivo_datos_codificados, low_memory=False)

X = df_datos_codificados.drop('DETERIORADO', axis='columns')
Y = df_datos_codificados['DETERIORADO']

# print('\nVariables de entrada (X):')
# print(X.info())
# print('-' * 92)
# print('\nVariable dependiente (Y):')
# print(Y.info())
# print(Y.value_counts().sort_index())

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y)

# %%
model = xgb.XGBClassifier(eval_metric='logloss')
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# %%
# Crear el scorer para optimizar por recall
scorer = make_scorer(recall_score)

# %%
# Configurar GridSearchCV para optimizar el recall
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scorer, cv=10, verbose=5)

# Entrenar con la búsqueda de hiperparámetros
grid_search.fit(x_train, y_train)

# Mostrar los mejores hiperparámetros encontrados
print(f'Mejores hiperparámetros: {grid_search.best_params_}')

# Predecir usando el mejor modelo
best_model = grid_search.best_estimator_
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.512 total time=   0.0s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.506 total time=   0.0s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.522 total time=   0.0s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.526 total time=   0.0s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.536 total time=   0.0s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.524 total time=   0.0s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.507 total time=   0.0s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.542 total time=   0.0s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.517 total time=   0.0s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8;, score=0.563 total time=   0.0s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.515 total time=   0.0s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.505 total time=   0.0s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.536 total time=   0.0s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.535 total time=   0.0s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.517 total time=   0.0s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.494 total time=   0.0s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.500 total time=   0.0s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.540 total time=   0.0s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.519 total time=   0.0s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0;, score=0.553 total time=   0.0s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.679 total time=   0.0s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.672 total time=   0.0s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.663 total time=   0.0s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.682 total time=   0.0s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.689 total time=   0.0s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.670 total time=   0.0s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.674 total time=   0.0s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.706 total time=   0.0s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.665 total time=   0.0s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8;, score=0.704 total time=   0.0s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.681 total time=   0.0s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.673 total time=   0.0s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.661 total time=   0.0s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.673 total time=   0.0s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.696 total time=   0.0s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.674 total time=   0.0s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.676 total time=   0.0s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.708 total time=   0.0s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.666 total time=   0.0s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0;, score=0.701 total time=   0.0s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.705 total time=   0.1s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.698 total time=   0.1s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.696 total time=   0.1s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.716 total time=   0.1s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.718 total time=   0.1s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.707 total time=   0.1s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.695 total time=   0.1s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.734 total time=   0.1s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.689 total time=   0.1s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8;, score=0.734 total time=   0.1s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.711 total time=   0.1s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.698 total time=   0.1s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.697 total time=   0.0s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.715 total time=   0.1s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.722 total time=   0.1s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.710 total time=   0.1s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.699 total time=   0.1s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.742 total time=   0.1s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.699 total time=   0.1s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.734 total time=   0.1s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.534 total time=   0.0s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.550 total time=   0.0s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.555 total time=   0.0s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.565 total time=   0.0s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.559 total time=   0.0s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.550 total time=   0.1s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.537 total time=   0.1s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.565 total time=   0.1s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.540 total time=   0.1s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=0.580 total time=   0.0s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.537 total time=   0.0s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.548 total time=   0.0s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.545 total time=   0.0s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.558 total time=   0.0s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.561 total time=   0.1s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.548 total time=   0.1s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.529 total time=   0.1s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.561 total time=   0.1s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.544 total time=   0.0s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=0.583 total time=   0.0s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.650 total time=   0.2s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.650 total time=   0.1s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.657 total time=   0.1s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.666 total time=   0.2s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.673 total time=   0.2s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.663 total time=   0.2s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.651 total time=   0.1s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.699 total time=   0.1s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.653 total time=   0.2s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=0.708 total time=   0.1s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.646 total time=   0.1s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.653 total time=   0.2s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.660 total time=   0.2s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.664 total time=   0.2s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.671 total time=   0.1s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.656 total time=   0.1s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.654 total time=   0.1s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.702 total time=   0.1s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.650 total time=   0.2s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=0.712 total time=   0.2s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.686 total time=   0.4s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.691 total time=   0.4s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.693 total time=   0.5s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.705 total time=   0.4s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.710 total time=   0.3s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.703 total time=   0.4s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.705 total time=   0.4s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.740 total time=   0.3s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.695 total time=   0.3s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=0.732 total time=   0.3s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.696 total time=   0.3s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.691 total time=   0.3s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.695 total time=   0.3s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.713 total time=   0.3s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.709 total time=   0.3s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.697 total time=   0.3s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.709 total time=   0.3s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.744 total time=   0.3s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.699 total time=   0.3s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=0.731 total time=   0.3s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.541 total time=   0.1s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.548 total time=   0.1s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.562 total time=   0.1s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.568 total time=   0.1s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.571 total time=   0.1s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.553 total time=   0.1s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.539 total time=   0.1s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.565 total time=   0.1s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.527 total time=   0.1s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=0.8;, score=0.583 total time=   0.1s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.561 total time=   0.1s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.548 total time=   0.4s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.555 total time=   0.2s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.558 total time=   0.3s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.571 total time=   0.2s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.549 total time=   0.3s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.552 total time=   0.2s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.561 total time=   0.3s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.528 total time=   0.2s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=50, subsample=1.0;, score=0.594 total time=   0.2s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.639 total time=   0.5s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.649 total time=   0.4s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.656 total time=   0.3s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.669 total time=   0.3s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.661 total time=   0.3s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.663 total time=   0.3s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.651 total time=   0.3s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.689 total time=   0.3s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.647 total time=   0.3s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.8;, score=0.702 total time=   0.3s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.642 total time=   0.2s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.655 total time=   0.3s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.669 total time=   0.2s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.670 total time=   0.3s
# [CV 5/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.667 total time=   0.3s
# [CV 6/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.657 total time=   0.3s
# [CV 7/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.646 total time=   0.2s
# [CV 8/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.681 total time=   0.2s
# [CV 9/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.645 total time=   0.2s
# [CV 10/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.705 total time=   0.3s
# [CV 1/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8;, score=0.682 total time=   0.6s
# [CV 2/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8;, score=0.682 total time=   0.7s
# [CV 3/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8;, score=0.699 total time=   0.6s
# [CV 4/10] END colsample_bytree=0.8, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=0.8;, score=0
10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1.0;, score=0.728 total time=   0.2s
# [CV 1/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.709 total time=   0.1s
# [CV 2/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.678 total time=   0.1s
# [CV 3/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.702 total time=   0.1s
# [CV 4/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.709 total time=   0.1s
# [CV 5/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.706 total time=   0.1s
# [CV 6/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.702 total time=   0.1s
# [CV 7/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.687 total time=   0.1s
# [CV 8/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.728 total time=   0.1s
# [CV 9/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.702 total time=   0.1s
# [CV 10/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=0.8;, score=0.729 total time=   0.1s
# [CV 1/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.702 total time=   0.1s
# [CV 2/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.683 total time=   0.1s
# [CV 3/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.706 total time=   0.1s
# [CV 4/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.707 total time=   0.1s
# [CV 5/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.709 total time=   0.1s
# [CV 6/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.710 total time=   0.1s
# [CV 7/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.705 total time=   0.1s
# [CV 8/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.732 total time=   0.1s
# [CV 9/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.704 total time=   0.1s
# [CV 10/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=50, subsample=1.0;, score=0.734 total time=   0.1s
# [CV 1/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.702 total time=   0.3s
# [CV 2/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.662 total time=   0.2s
# [CV 3/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.696 total time=   0.2s
# [CV 4/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.706 total time=   0.2s
# [CV 5/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.697 total time=   0.2s
# [CV 6/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.693 total time=   0.2s
# [CV 7/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.682 total time=   0.2s
# [CV 8/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.717 total time=   0.2s
# [CV 9/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.682 total time=   0.2s
# [CV 10/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=0.8;, score=0.721 total time=   0.3s
# [CV 1/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.694 total time=   0.2s
# [CV 2/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.676 total time=   0.2s
# [CV 3/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.705 total time=   0.2s
# [CV 4/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.697 total time=   0.2s
# [CV 5/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.700 total time=   0.2s
# [CV 6/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.713 total time=   0.2s
# [CV 7/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.695 total time=   0.2s
# [CV 8/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.721 total time=   0.2s
# [CV 9/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.698 total time=   0.2s
# [CV 10/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=100, subsample=1.0;, score=0.725 total time=   0.2s
# [CV 1/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8;, score=0.681 total time=   0.5s
# [CV 2/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8;, score=0.650 total time=   0.8s
# [CV 3/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8;, score=0.689 total time=   0.7s
# [CV 4/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8;, score=0.699 total time=   0.6s
# [CV 5/10] END colsample_bytree=1.0, learning_rate=0.2, max_depth=7, n_estimators=200, subsample=0.8;, score=0.680 total time=   0.6s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scorer, cv=10, verbose=5)
#       4 # Entrenar con la búsqueda de hiperparámetros
# ----> 5 grid_search.fit(x_train, y_train)
#       7 # Mostrar los mejores hiperparámetros encontrados
#       8 print(f'Mejores hiperparámetros: {grid_search.best_params_}')
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\sklearn\model_selection\_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\sklearn\model_selection\_search.py:1572, in GridSearchCV._run_search(self, evaluate_candidates)
#    1570 def _run_search(self, evaluate_candidates):
#    1571     """Search all candidates in param_grid"""
# -> 1572     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\sklearn\model_selection\_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\xgboost\sklearn.py:1531, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1511 model, metric, params = self._configure_fit(xgb_model, params)
#    1512 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1513     missing=self.missing,
#    1514     X=X,
#    (...)
#    1528     feature_types=self.feature_types,
#    1529 )
# -> 1531 self._Booster = train(
#    1532     params,
#    1533     train_dmatrix,
#    1534     self.get_num_boosting_rounds(),
#    1535     evals=evals,
#    1536     early_stopping_rounds=self.early_stopping_rounds,
#    1537     evals_result=evals_result,
#    1538     obj=obj,
#    1539     custom_metric=metric,
#    1540     verbose_eval=verbose,
#    1541     xgb_model=model,
#    1542     callbacks=self.callbacks,
#    1543 )
#    1545 if not callable(self.objective):
#    1546     self.objective = params["objective"]
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File d:\0.Proyectos_VSCODE\Aguas_residuales\Modelo_deterioro_tramos\.venv\lib\site-packages\xgboost\core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# Hacer predicciones
y_pred = best_model.predict(x_test)

# %%
# Evaluar el modelo con varias métricas
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

# Mostrar los resultados
print(f'Accuracy: {accuracy:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'Precision: {precision:.4f}')
# Out:
# Accuracy: 0.7588
# Recall: 0.7755
# F1 Score: 0.7419
# Precision: 0.7111
